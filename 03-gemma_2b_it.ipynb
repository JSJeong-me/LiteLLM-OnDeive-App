# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/Local-LLM/blob/main/03-gemma_2b_it.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### https://huggingface.co/google/gemma-2b-it

# %%
# !pip install -qU "transformers==4.38.0" --upgrade
# !pip install huggingface-hub

# %%
import huggingface_hub

huggingface_hub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip install accelerate

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it", device_map="auto")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the cpu.

# %%
input_text = "Write me a poem about Machine Learning."
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1178: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# <bos>Write me a poem about Machine Learning.
#
# Machines, they weave and they learn,
# From

# %%
import torch
from transformers import AutoTokenizer
# from transformers import AutoTokenizer, AutoModelForCausalLM

model = "google/gemma-2b-it"

tokenizer = AutoTokenizer.from_pretrained(model)

# %%
from transformers import pipeline

pipeline = pipeline(
    "text-generation",
    model=model,
    model_kwargs={"torch_dtype": torch.bfloat16},
    device="cuda",
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
messages = [
        {"role": "user", "content": "Who are you? Please, answer in pirate-speak."},
]

# %%
prompt = pipeline.tokenizer.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True)

# %%
outputs = pipeline(
    prompt,
    max_new_tokens=256,
    add_special_tokens=True,
    do_sample=True,
    temperature=0.7,
    top_k=50,
    top_p=0.95
)

# %%
print(outputs[0]["generated_text"][len(prompt):])
# Out:
# Ahoy, mateys! I be the scurvy-stricken buccaneer, Captain Calico Jack. I sail the high seas in search of adventure, plunder, and a good rum punch at the end of the day.
#
# So, if you be lost at sea, don't hesitate to hail me. I'll show ye the ropes and point you in the right direction. And if you be in need of a matey, I'll be the first one to lend a helping hand.
#
# So hoist the sails, me hearties, and let the adventure begin!
